# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("shivamb/netflix-shows")

print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'netflix-shows' dataset.
# Path to dataset files: /kaggle/input/netflix-shows

# %%
path="/kaggle/input/netflix-shows"

# %%
import pandas as pd

# %%
df=pd.read_csv(path+"/netflix_titles.csv")

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df.head(10)
# Out:
#   show_id     type                             title  \
# 0      s1    Movie              Dick Johnson Is Dead
# 1      s2  TV Show                     Blood & Water
# 2      s3  TV Show                         Ganglands
# 3      s4  TV Show             Jailbirds New Orleans
# 4      s5  TV Show                      Kota Factory
# 5      s6  TV Show                     Midnight Mass
# 6      s7    Movie  My Little Pony: A New Generation
# 7      s8    Movie                           Sankofa
# 8      s9  TV Show     The Great British Baking Show
# 9     s10    Movie                      The Starling
#
#                         director  \
# 0                Kirsten Johnson
# 1                            NaN
# 2                Julien Leclercq
# 3                            NaN
# 4                            NaN
# 5                  Mike Flanagan
# 6  Robert Cullen, José Luis Ucha
# 7                   Haile Gerima
# 8                Andy Devonshire
# 9                 Theodore Melfi
#
# ...

# %%
df.tail()
# Out:
#      show_id     type        title         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#              date_added  release_year rating   duration  \
# 8802  November 20, 2019          2007      R    158 min
# 8803       July 1, 2019          2018  TV-Y7  2 Seasons
# ...

# %%
df.tail(10)
# Out:
#      show_id     type               title                 director  \
# 8797   s8798  TV Show           Zak Storm                      NaN
# 8798   s8799    Movie            Zed Plus  Chandra Prakash Dwivedi
# 8799   s8800    Movie               Zenda           Avadhoot Gupte
# 8800   s8801  TV Show  Zindagi Gulzar Hai                      NaN
# 8801   s8802    Movie             Zinzana          Majid Al Ansari
# 8802   s8803    Movie              Zodiac            David Fincher
# 8803   s8804  TV Show         Zombie Dumb                      NaN
# 8804   s8805    Movie          Zombieland          Ruben Fleischer
# 8805   s8806    Movie                Zoom             Peter Hewitt
# 8806   s8807    Movie              Zubaan              Mozez Singh
#
#                                                    cast  \
# 8797  Michael Johnston, Jessica Gee-George, Christin...
# 8798  Adil Hussain, Mona Singh, K.K. Raina, Sanjay M...
# 8799  Santosh Juvekar, Siddharth Chandekar, Sachit P...
# ...

# %%
df.shape
# Out:
# (8807, 12)

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
df.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
df['release_year']
# Out:
# 0       2020
# 1       2021
# 2       2021
# 3       2021
# 4       2021
#         ...
# 8802    2007
# 8803    2018
# 8804    2009
# 8805    2006
# 8806    2015
# Name: release_year, Length: 8807, dtype: int64

# %%
df[["title","release_year"]]
# Out:
#                       title  release_year
# 0      Dick Johnson Is Dead          2020
# 1             Blood & Water          2021
# 2                 Ganglands          2021
# 3     Jailbirds New Orleans          2021
# 4              Kota Factory          2021
# ...                     ...           ...
# 8802                 Zodiac          2007
# 8803            Zombie Dumb          2018
# 8804             Zombieland          2009
# 8805                   Zoom          2006
# 8806                 Zubaan          2015
#
# [8807 rows x 2 columns]

# %% [markdown]
# movies that are released after 2020

# %%
df[df['release_year']>2020]
# Out:
#      show_id     type                      title         director  \
# 1         s2  TV Show              Blood & Water              NaN
# 2         s3  TV Show                  Ganglands  Julien Leclercq
# 3         s4  TV Show      Jailbirds New Orleans              NaN
# 4         s5  TV Show               Kota Factory              NaN
# 5         s6  TV Show              Midnight Mass    Mike Flanagan
# ...      ...      ...                        ...              ...
# 1468   s1469    Movie  What Happened to Mr. Cha?     Kim Dong-kyu
# 1551   s1552  TV Show                      Hilda              NaN
# 1696   s1697  TV Show               Polly Pocket              NaN
# 2920   s2921  TV Show              Love Is Blind              NaN
# 8437   s8438  TV Show     The Netflix Afterparty              NaN
#
#                                                    cast  \
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# ...

# %%
df[df['country']=='India']
# Out:
#      show_id     type                          title                 director  \
# 4         s5  TV Show                   Kota Factory                      NaN
# 24       s25    Movie                          Jeans               S. Shankar
# 39       s40  TV Show                   Chhota Bheem                      NaN
# 50       s51  TV Show                  Dharmakshetra                      NaN
# 66       s67  TV Show  Raja Rasoi Aur Anya Kahaniyan                      NaN
# ...      ...      ...                            ...                      ...
# 8773   s8774    Movie            Yanda Kartavya Aahe             Kedar Shinde
# 8775   s8776  TV Show                Yeh Meri Family                      NaN
# 8798   s8799    Movie                       Zed Plus  Chandra Prakash Dwivedi
# 8799   s8800    Movie                          Zenda           Avadhoot Gupte
# 8806   s8807    Movie                         Zubaan              Mozez Singh
#
# ...

# %%
df[
   (df['country']=='India')
   &
   (df['type']=="Movie")
   &
   (df['release_year']>2020)
   ]
# Out:
#      show_id   type                          title  \
# 190     s191  Movie                     Thimmarusu
# 551     s552  Movie                Haseen Dillruba
# 735     s736  Movie                        Sarbath
# 850     s851  Movie                       99 Songs
# 871     s872  Movie             Sardar Ka Grandson
# 873     s874  Movie                          Ahaan
# 877     s878  Movie                   Cinema Bandi
# 903     s904  Movie                        Nayattu
# 909     s910  Movie                      Milestone
# 959     s960  Movie                   The Disciple
# 998     s999  Movie           Searching For Sheela
# 1023   s1024  Movie                Ajeeb Daastaans
# 1037   s1038  Movie             Tuesdays & Fridays
# 1087   s1088  Movie                          Roohi
# 1098   s1099  Movie                        Mandela
# 1108   s1109  Movie                           Irul
# 1165   s1166  Movie                       Pagglait
# ...

# %%
df[
   (df['country']=='India')
   &
   (df['type']=="TV Show")
   &
   (df['release_year']>2020)
   ]
# Out:
#      show_id     type                               title  \
# 4         s5  TV Show                        Kota Factory
# 39       s40  TV Show                        Chhota Bheem
# 297     s298  TV Show                            Navarasa
# 876     s877  TV Show                        Alma Matters
# 918     s919  TV Show                      Lava Ka Dhaava
# 1093   s1094  TV Show                         The Big Day
# 1227   s1228  TV Show                       Bombay Begums
# 1293   s1294  TV Show                       Pitta Kathalu
# 1429   s1430  TV Show  Mighty Little Bheem: Kite Festival
#
#                                                director  \
# 4                                                   NaN
# 39                                                  NaN
# 297   Bejoy Nambiar, Priyadarshan, Karthik Narain, V...
# 876                                                 NaN
# 918                                                 NaN
# ...

# %% [markdown]
# sorting

# %%
df.sort_values("release_year",ascending=False)
# Out:
#      show_id     type                                          title  \
# 1         s2  TV Show                                  Blood & Water
# 2         s3  TV Show                                      Ganglands
# 3         s4  TV Show                          Jailbirds New Orleans
# 31       s32  TV Show                             Chicago Party Aunt
# 30       s31    Movie                                Ankahi Kahaniya
# ...      ...      ...                                            ...
# 8739   s8740    Movie             Why We Fight: The Battle of Russia
# 8660   s8661    Movie  Undercover: How to Operate Behind Enemy Lines
# 7790   s7791    Movie                                 Prelude to War
# 8205   s8206    Movie                           The Battle of Midway
# 4250   s4251  TV Show              Pioneers: First Women Filmmakers*
#
#                                                director  \
# 1                                                   NaN
# ...

# %%
df.sort_values("title")
# Out:
#      show_id     type                          title  \
# 2036   s2037    Movie                         #Alive
# 2304   s2305    Movie  #AnneFrank - Parallel Stories
# 2481   s2482    Movie              #FriendButMarried
# 2324   s2325    Movie            #FriendButMarried 2
# 5973   s5974    Movie                          #Roxy
# ...      ...      ...                            ...
# 6177   s6178  TV Show                       忍者ハットリくん
# 4914   s4915  TV Show                           海的儿子
# 7101   s7102  TV Show                           마녀사냥
# 5022   s5023    Movie                        반드시 잡는다
# 7108   s7109    Movie            최강전사 미니특공대 : 영웅의 탄생
#
#                          director  \
# 2036                       Cho Il
# 2304  Sabina Fedeli, Anna Migotto
# 2481                Rako Prijanto
# 2324                Rako Prijanto
# 5973              Michael Kennedy
# ...                           ...
# 6177                          NaN
# 4914                          NaN
# ...

# %% [markdown]
# EDA  exploratory data analysis

# %%
df.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %% [markdown]
# **real world datasets always contain missing values**

# %%
df[df['director'].isnull()]
# Out:
#      show_id     type                                title director  \
# 1         s2  TV Show                        Blood & Water      NaN
# 3         s4  TV Show                Jailbirds New Orleans      NaN
# 4         s5  TV Show                         Kota Factory      NaN
# 10       s11  TV Show  Vendetta: Truth, Lies and The Mafia      NaN
# 14       s15  TV Show      Crime Stories: India Detectives      NaN
# ...      ...      ...                                  ...      ...
# 8795   s8796  TV Show                      Yu-Gi-Oh! Arc-V      NaN
# 8796   s8797  TV Show                           Yunus Emre      NaN
# 8797   s8798  TV Show                            Zak Storm      NaN
# 8800   s8801  TV Show                   Zindagi Gulzar Hai      NaN
# 8803   s8804  TV Show                          Zombie Dumb      NaN
#
#                                                    cast  \
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# ...

# %% [markdown]
# NaN means null value

# %%
df['director'].fillna('Unknown',inplace=True)
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water          Unknown
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans          Unknown
# 4         s5  TV Show           Kota Factory          Unknown
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb          Unknown
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df['cast'].fillna('unknown',inplace=True)
df
# Out:
# /tmp/ipykernel_3875/2442951224.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['cast'].fillna('unknown',inplace=True)
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water          Unknown
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans          Unknown
# 4         s5  TV Show           Kota Factory          Unknown
# ...

# %%
df.groupby('type').size()
# Out:
# type
# Movie      6131
# TV Show    2676
# dtype: int64

# %%
df.groupby('country').size()
# Out:
# country
# , France, Algeria                                       1
# , South Korea                                           1
# Argentina                                              56
# Argentina, Brazil, France, Poland, Germany, Denmark     1
# Argentina, Chile                                        2
#                                                        ..
# Venezuela                                               1
# Venezuela, Colombia                                     1
# Vietnam                                                 7
# West Germany                                            1
# Zimbabwe                                                1
# Length: 748, dtype: int64

# %%
country_data=df.groupby("country").size()

# %%
country_data.sort_values(ascending=False)
# Out:
# country
# United States          2818
# India                   972
# United Kingdom          419
# Japan                   245
# South Korea             199
#                        ...
# Australia, Iraq           1
# Venezuela                 1
# Venezuela, Colombia       1
# West Germany              1
# , South Korea             1
# Length: 748, dtype: int64

# %%
df.groupby("release_year").size()
# Out:
# release_year
# 1925       1
# 1942       2
# 1943       3
# 1944       3
# 1945       4
#         ...
# 2017    1032
# 2018    1147
# 2019    1030
# 2020     953
# 2021     592
# Length: 74, dtype: int64

# %%
df['rating'].value_counts()
# Out:
# rating
# TV-MA       3207
# TV-14       2160
# TV-PG        863
# R            799
# PG-13        490
# TV-Y7        334
# TV-Y         307
# PG           287
# TV-G         220
# NR            80
# G             41
# TV-Y7-FV       6
# NC-17          3
# UR             3
# 74 min         1
# 84 min         1
# 66 min         1
# Name: count, dtype: int64

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water          Unknown
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans          Unknown
# 4      s5  TV Show           Kota Factory          Unknown
#
#                                                 cast        country  \
# 0                                            unknown  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                            unknown            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %% [markdown]
# how to find only comedy movies??
#
# > Add blockquote

# %%
df[
    df['listed_in'].str.contains("Comedy",na=False)
]
# Out:
#      show_id     type                                              title  \
# 278     s279    Movie                        Lokillo: Nothing's the Same
# 359     s360    Movie                       The Original Kings of Comedy
# 388     s389  TV Show            Plastic Cup Boyz: Laughing My Mask Off!
# 400     s401  TV Show  Revelations: The Masters of the Universe: Reve...
# 475     s476    Movie                                       The Stand-Up
# ...      ...      ...                                                ...
# 7812   s7813  TV Show                                   Queens of Comedy
# 7813   s7814  TV Show                                   Queens vs. Kings
# 7908   s7909  TV Show                       Russell Peters vs. the World
# 7909   s7910    Movie                          Russell Peters: Notorious
# 8437   s8438  TV Show                             The Netflix Afterparty
#
#                              director  \
# 278                    Julián Gaviria
# ...

# %% [markdown]
# find horror movies

# %%
df[
    df["listed_in"].str.contains("Horror",na=False)
]
# Out:
#      show_id     type              title  \
# 5         s6  TV Show      Midnight Mass
# 28       s29    Movie         Dark Skies
# 42       s43    Movie             Jaws 2
# 43       s44    Movie             Jaws 3
# 44       s45    Movie  Jaws: The Revenge
# ...      ...      ...                ...
# 8722   s8723    Movie  What Lies Beneath
# 8760   s8761    Movie   Would You Rather
# 8765   s8766    Movie                 XX
# 8782   s8783    Movie        Yoga Hosers
# 8804   s8805    Movie         Zombieland
#
#                                                director  \
# 5                                         Mike Flanagan
# 28                                        Scott Stewart
# 42                                       Jeannot Szwarc
# 43                                            Joe Alves
# 44                                       Joseph Sargent
# ...                                                 ...
# 8722                                    Robert Zemeckis
# ...

# %%
df[
    df["listed_in"].str.contains("Action",na=False)
]
# Out:
#      show_id     type                          title           director  \
# 2         s3  TV Show                      Ganglands    Julien Leclercq
# 11       s12  TV Show               Bangkok Breaking  Kongkiat Komesiri
# 19       s20  TV Show                         Jaguar            Unknown
# 21       s22  TV Show         Resurrection: Ertugrul            Unknown
# 36       s37    Movie                 The Stronghold     Cédric Jimenez
# ...      ...      ...                            ...                ...
# 8766   s8767    Movie                            XXx          Rob Cohen
# 8767   s8768    Movie        XXX: State of the Union       Lee Tamahori
# 8772   s8773    Movie          Yamla Pagla Deewana 2     Sangeeth Sivan
# 8790   s8791    Movie  You Don't Mess with the Zohan       Dennis Dugan
# 8792   s8793    Movie                    Young Tiger             Mu Chu
#
#                                                    cast        country  \
# ...

# %%
df["Content Age"]=(2026-df['release_year'])
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water          Unknown
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans          Unknown
# 4         s5  TV Show           Kota Factory          Unknown
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb          Unknown
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                               unknown  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.sort_values("Content Age",ascending=True)
# Out:
#      show_id     type                                          title  \
# 19       s20  TV Show                                         Jaguar
# 18       s19    Movie                                      Intrusion
# 15       s16  TV Show                              Dear White People
# 14       s15  TV Show                Crime Stories: India Detectives
# 36       s37    Movie                                 The Stronghold
# ...      ...      ...                                            ...
# 8660   s8661    Movie  Undercover: How to Operate Behind Enemy Lines
# 8763   s8764    Movie                WWII: Report from the Aleutians
# 7790   s7791    Movie                                 Prelude to War
# 8205   s8206    Movie                           The Battle of Midway
# 4250   s4251  TV Show              Pioneers: First Women Filmmakers*
#
#             director                                               cast  \
# ...

# %%
pivot=pd.pivot_table(
    df,
    index='type',
    values='release_year',
    aggfunc='count'
)
pivot
# Out:
#          release_year
# type
# Movie            6131
# TV Show          2676

# %% [markdown]
# pivot tables summarize the given datasets
#
# these pivot tables are similar to excels used in companies

# %% [markdown]
# 1.which country has most tv series content
# 2.which genre appears the most?
# 3.why are missing values are danger?
# 4.find out difference between movies and tv shows count
# 5.why filtering is important?

# %%
df['country'].value_counts().head(1)
# Out:
# country
# United States    2818
# Name: count, dtype: int64

# %%
df['listed_in'].value_counts().head(1)
# Out:
# listed_in
# Dramas, International Movies    362
# Name: count, dtype: int64

# %% [markdown]
# they reduce data quality
# sometimes wrong analytics
# incorrect prediction
# incomplete results/reports/answers

# %% [markdown]
# filtering will help us extract useful data  indian movies  comedy movies

# %%
df['type'].value_counts()
# Out:
# type
# Movie      6131
# TV Show    2676
# Name: count, dtype: int64

# %%
print(6131-2676)
# Out:
# 3455

# %%
df.sort_values("release_year").head(1)
# Out:
#      show_id     type                              title director     cast  \
# 4250   s4251  TV Show  Pioneers: First Women Filmmakers*  Unknown  unknown
#
#      country         date_added  release_year rating  duration listed_in  \
# 4250     NaN  December 30, 2018          1925  TV-14  1 Season  TV Shows
#
#                                             description  Content Age
# 4250  This collection restores films from women who ...          101

# %%
df[
  df['title'].str.contains(
      "Love",na=False
  )
]
# Out:
#      show_id     type                           title  \
# 25       s26  TV Show            Love on the Spectrum
# 158     s159    Movie         Love Don't Cost a Thing
# 159     s160    Movie                  Love in a Puff
# 206     s207    Movie       LSD: Love, Sex Aur Dhokha
# 227     s228    Movie                     Really Love
# ...      ...      ...                             ...
# 8567   s8568  TV Show  The Year of Happiness and Love
# 8575   s8576  TV Show                 This Is My Love
# 8649   s8650    Movie           Two Lovers and a Bear
# 8721   s8722  TV Show                   What Is Love?
# 8725   s8726    Movie            What's Up With Love?
#
#                        director  \
# 25                      Unknown
# 158                   Troy Byer
# 159              Pang Ho-cheung
# 206            Dibakar Banerjee
# 227       Angel Kristi Williams
# ...                         ...
# 8567                    Unknown
# 8575                    Unknown
# ...
