# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("sudhanvahg/indian-crimes-dataset")

print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'indian-crimes-dataset' dataset.
# Path to dataset files: /kaggle/input/indian-crimes-dataset

# %%
path="/kaggle/input/indian-crimes-dataset"

# %%
import pandas as pd
df=pd.read_csv(path+"/crime_dataset_india.csv")

# %%
df.head()
# Out:
# /usr/local/lib/python3.12/dist-packages/google/colab/_dataframe_summarizer.py:88: UserWarning: Parsing dates in %d-%m-%Y %H:%M format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   cast_date_col = pd.to_datetime(column, errors="coerce")
#    Report Number     Date Reported Date of Occurrence Time of Occurrence  \
# 0              1  02-01-2020 00:00   01-01-2020 00:00   01-01-2020 01:11
# 1              2  01-01-2020 19:00   01-01-2020 01:00   01-01-2020 06:26
# 2              3  02-01-2020 05:00   01-01-2020 02:00   01-01-2020 14:30
# 3              4  01-01-2020 05:00   01-01-2020 03:00   01-01-2020 14:46
# 4              5  01-01-2020 21:00   01-01-2020 04:00   01-01-2020 16:51
#
#         City  Crime Code Crime Description  Victim Age Victim Gender  \
# 0  Ahmedabad         576    IDENTITY THEFT          16             M
# 1    Chennai         128          HOMICIDE          37             M
# ...

# %%
df.sample(15)
# Out:
#        Report Number     Date Reported Date of Occurrence Time of Occurrence  \
# 13819          13820  01-08-2021 12:00   07-29-2021 19:00   29-07-2021 23:10
# 14140          14141  12-08-2021 16:00   08-12-2021 04:00   12-08-2021 21:03
# 27513          27514  22-02-2023 01:00   02-20-2023 09:00   20-02-2023 18:38
# 17898          17899  18-01-2022 05:00   01-15-2022 18:00   15-01-2022 23:45
# 400              401  18-01-2020 16:00   01-17-2020 16:00   17-01-2020 19:49
# 39086          39087  19-06-2024 10:00   06-16-2024 14:00   16-06-2024 17:08
# 3255            3256  18-05-2020 09:00   05-15-2020 15:00   16-05-2020 02:43
# 36993          36994  22-03-2024 11:00   03-21-2024 09:00   22-03-2024 04:13
# 33760          33761  09-11-2023 12:00   11-07-2023 16:00   08-11-2023 01:36
# 36024          36025  10-02-2024 05:00   02-10-2024 00:00   10-02-2024 20:24
# 15422          15423  07-10-2021 08:00   10-04-2021 14:00   05-10-2021 11:02
# ...

# %%
df.memory_usage()
# Out:
# Index                    132
# Report Number         321280
# Date Reported         321280
# Date of Occurrence    321280
# Time of Occurrence    321280
# City                  321280
# Crime Code            321280
# Crime Description     321280
# Victim Age            321280
# Victim Gender         321280
# Weapon Used           321280
# Crime Domain          321280
# Police Deployed       321280
# Case Closed           321280
# Date Case Closed      321280
# dtype: int64

# %%
df['City'].value_counts().head(10)
# Out:
# City
# Delhi        5400
# Mumbai       4415
# Bangalore    3588
# Hyderabad    2881
# Kolkata      2518
# Chennai      2493
# Pune         2212
# Ahmedabad    1817
# Jaipur       1479
# Lucknow      1456
# Name: count, dtype: int64

# %%
df["Crime Description"].value_counts()
# Out:
# Crime Description
# BURGLARY               1980
# VANDALISM              1975
# FRAUD                  1965
# DOMESTIC VIOLENCE      1932
# FIREARM OFFENSE        1931
# ROBBERY                1928
# KIDNAPPING             1920
# IDENTITY THEFT         1918
# SEXUAL ASSAULT         1917
# ASSAULT                1915
# TRAFFIC VIOLATION      1915
# PUBLIC INTOXICATION    1912
# HOMICIDE               1909
# CYBERCRIME             1899
# ILLEGAL POSSESSION     1895
# ARSON                  1894
# DRUG OFFENSE           1890
# EXTORTION              1873
# COUNTERFEITING         1871
# VEHICLE - STOLEN       1862
# SHOPLIFTING            1859
# Name: count, dtype: int64

# %%
df['City'].value_counts().head()
# Out:
# City
# Delhi        5400
# Mumbai       4415
# Bangalore    3588
# Hyderabad    2881
# Kolkata      2518
# Name: count, dtype: int64

# %%
df[
    df['Crime Description']=="SHOPLIFTING"
]
# Out:
#        Report Number     Date Reported Date of Occurrence Time of Occurrence  \
#
Fujiko F. Fujio Characters: Great Assembly! Sl...      3DS
# 16582  16585                                    Planet Monsters      GBA
# 16583  16586                                     Carmageddon 64      N64
# 16589  16592  Chou Ezaru wa Akai Hana: Koi wa Tsuki ni Shiru...      PSV
#
#          Year   Genre                  Publisher  NA_Sales  EU_Sales  \
# ...

# %%
df[(df['Genre']=="Sports")&(df['Year']>2015)]
# Out:
#         Rank                                Name Platform    Year   Genre  \
# 221      222                             FIFA 17      PS4  2016.0  Sports
# 1224    1226                             FIFA 17     XOne  2016.0  Sports
# 1628    1630                       Madden NFL 17      PS4  2016.0  Sports
# 1701    1703                            NBA 2K17      PS4  2016.0  Sports
# 2342    2344                     EA Sports UFC 2      PS4  2016.0  Sports
# 2505    2507                       Madden NFL 17     XOne  2016.0  Sports
# 3145    3147                            NBA 2K17     XOne  2016.0  Sports
# 4820    4822                     EA Sports UFC 2     XOne  2016.0  Sports
# 5056    5058                             FIFA 17      PS3  2016.0  Sports
# 6136    6138           Pro Evolution Soccer 2017      PS4  2016.0  Sports
# 6205    6207                      UEFA Euro 2016      PS4  2016.0  Sports
# 7072    7074                       Rocket League      PS4  2016.0  Sports
# ...

# %%
df[(df['Platform']=='PS4')&(df['Genre']=='Action')]
# Out:
#         Rank                                               Name Platform  \
# 44        45                                 Grand Theft Auto V      PS4
# 236      237                                     The Last of Us      PS4
# 243      244             Uncharted: The Nathan Drake Collection      PS4
# 280      281                                         Watch Dogs      PS4
# 304      305                            Assassin's Creed: Unity      PS4
# ...      ...                                                ...      ...
# 16136  16139                    Dragon's Dogma Online: Season 2      PS4
# 16175  16178                                         Republique      PS4
# 16220  16223                       Dynasty Warriors: Eiketsuden      PS4
# 16260  16263                                            Paragon      PS4
# 16550  16553  God Eater Off Shot: Tachibana Sakuya-hen Twin ...      PS4
#
#          Year   Genre                    Publisher  NA_Sales  EU_Sales  \
# ...

# %%
df[(df['Platform']=='PS4')&(df['Genre']=='Action')&(df['Year']>2015)]
# Out:
#         Rank                                               Name Platform  \
# 770      772                                    Far Cry: Primal      PS4
# 1156    1158                                       No Man's Sky      PS4
# 2457    2459                                   MLB 16: The Show      PS4
# 3149    3151                             LEGO Marvel's Avengers      PS4
# 3746    3748                  Lego Star Wars: The Force Awakens      PS4
# 5172    5174                                 Resident Evil Zero      PS4
# 5621    5623                                   TrackMania Turbo      PS4
# 6203    6205  Dragon Quest Heroes II: Twin Kings and the Pro...      PS4
# 7497    7499                             Attack on Titan (KOEI)      PS4
# 7892    7894    The Heavy Rain and Beyond: Two Souls Collection      PS4
# 9878    9880                                      7 Days to Die      PS4
# 9993    9995                  Dead Island Definitive Collection      PS4
# ...

# %%
df["Publisher"].value_counts().head()
# Out:
# Publisher
# Electronic Arts                 1351
# Activision                       975
# Namco Bandai Games               932
# Ubisoft                          921
# Konami Digital Entertainment     832
# Name: count, dtype: int64

# %%
df.groupby("Genre")["Global_Sales"].sum()
# Out:
# Genre
# Action          1751.18
# Adventure        239.04
# Fighting         448.91
# Misc             809.96
# Platform         831.37
# Puzzle           244.95
# Racing           732.04
# Role-Playing     927.37
# Shooter         1037.37
# Simulation       392.20
# Sports          1330.93
# Strategy         175.12
# Name: Global_Sales, dtype: float64

# %%
genre_sales=df.groupby("Genre")["Global_Sales"].sum()

# %%
print(genre_sales.sort_values(ascending=True))
# Out:
# Genre
# Strategy         175.12
# Adventure        239.04
# Puzzle           244.95
# Simulation       392.20
# Fighting         448.91
# Racing           732.04
# Misc             809.96
# Platform         831.37
# Role-Playing     927.37
# Shooter         1037.37
# Sports          1330.93
# Action          1751.18
# Name: Global_Sales, dtype: float64

# %%
platform_sales=df.groupby("Platform")["Global_Sales"].sum()

print(platform_sales.sort_values(ascending=False))
# Out:
# Platform
# PS2     1255.64
# X360     979.96
# PS3      957.84
# Wii      926.71
# DS       822.49
# PS       730.66
# GBA      318.50
# PSP      296.28
# PS4      278.10
# PC       258.82
# XB       258.26
# GB       255.45
# NES      251.07
# 3DS      247.46
# N64      218.88
# SNES     200.05
# GC       199.36
# XOne     141.06
# 2600      97.08
# WiiU      81.86
# PSV       61.93
# SAT       33.59
# GEN       28.36
# DC        15.97
# SCD        1.87
# NG         1.44
# WS         1.42
# TG16       0.16
# 3DO        0.10
# GG         0.04
# PCFX       0.03
# Name: Global_Sales, dtype: float64

# %%
publisher_sales=df.groupby("Publisher")["Global_Sales"].sum()

print(publisher_sales.sort_values(ascending=False).head())
# Out:
# Publisher
# Nintendo                       1786.56
# Electronic Arts                1110.32
# Activision                      727.46
# Sony Computer Entertainment     607.50
# Ubisoft                         474.72
# Name: Global_Sales, dtype: float64

# %%
year_sales=df.groupby("Year")["Global_Sales"].sum()

year_sales
# Out:
# Year
# 1980.0     11.38
# 1981.0     35.77
# 1982.0     28.86
# 1983.0     16.79
# 1984.0     50.36
# 1985.0     53.94
# 1986.0     37.07
# 1987.0     21.74
# 1988.0     47.22
# 1989.0     73.45
# 1990.0     49.39
# 1991.0     32.23
# 1992.0     76.16
# 1993.0     45.98
# 1994.0     79.17
# 1995.0     88.11
# 1996.0    199.15
# 1997.0    200.98
# 1998.0    256.47
# 1999.0    251.27
# 2000.0    201.56
# 2001.0    331.47
# 2002.0    395.52
# 2003.0    357.85
# 2004.0    419.31
# 2005.0    459.94
# 2006.0    521.04
# 2007.0    611.13
# 2008.0    678.90
# 2009.0    667.30
# 2010.0    600.45
# 2011.0    515.99
# 2012.0    363.54
# 2013.0    368.11
# 2014.0    337.05
# 2015.0    264.44
# 2016.0     70.93
# 2017.0      0.05
# 2020.0      0.29
# Name: Global_Sales, dtype: float64

# %%
year_sales.sort_values(ascending=True)
year_sales
# Out:
# Year
# 1980.0     11.38
# 1981.0     35.77
# 1982.0     28.86
# 1983.0     16.79
# 1984.0     50.36
# 1985.0     53.94
# 1986.0     37.07
# 1987.0     21.74
# 1988.0     47.22
# 1989.0     73.45
# 1990.0     49.39
# 1991.0     32.23
# 1992.0     76.16
# 1993.0     45.98
# 1994.0     79.17
# 1995.0     88.11
# 1996.0    199.15
# 1997.0    200.98
# 1998.0    256.47
# 1999.0    251.27
# 2000.0    201.56
# 2001.0    331.47
# 2002.0    395.52
# 2003.0    357.85
# 2004.0    419.31
# 2005.0    459.94
# 2006.0    521.04
# 2007.0    611.13
# 2008.0    678.90
# 2009.0    667.30
# 2010.0    600.45
# 2011.0    515.99
# 2012.0    363.54
# 2013.0    368.11
# 2014.0    337.05
# 2015.0    264.44
# 2016.0     70.93
# 2017.0      0.05
# 2020.0      0.29
# Name: Global_Sales, dtype: float64

# %%
df[["NA_Sales",
    "EU_Sales",
    "JP_Sales",
    "Other_Sales"]].sum()
# Out:
# NA_Sales       4392.95
# EU_Sales       2434.13
# JP_Sales       1291.02
# Other_Sales     797.75
# dtype: float64

# %%
df[df["Name"].str.contains("Grand Theft Auto",na=False)]
# Out:
#         Rank                                               Name Platform  \
# 16        17                                 Grand Theft Auto V      PS3
# 17        18                      Grand Theft Auto: San Andreas      PS2
# 23        24                                 Grand Theft Auto V     X360
# 24        25                        Grand Theft Auto: Vice City      PS2
# 38        39                               Grand Theft Auto III      PS2
# 44        45                                 Grand Theft Auto V      PS4
# 51        52                                Grand Theft Auto IV     X360
# 56        57                                Grand Theft Auto IV      PS3
# 90        91             Grand Theft Auto: Liberty City Stories      PSP
# 197      198                                 Grand Theft Auto V     XOne
# 198      199                Grand Theft Auto: Vice City Stories      PSP
# 360      361             Grand Theft Auto: Liberty City Stories      PS2
# ...

# %%
df[df["Name"].str.contains("Far Cry",na=False)]
# Out:
#         Rank                         Name Platform    Year    Genre Publisher  \
# 295      296                    Far Cry 4      PS4  2014.0  Shooter   Ubisoft
# 382      383                    Far Cry 3      PS3  2012.0  Shooter   Ubisoft
# 459      460                    Far Cry 3     X360  2012.0  Shooter   Ubisoft
# 770      772              Far Cry: Primal      PS4  2016.0   Action   Ubisoft
# 1147    1149                    Far Cry 4     XOne  2014.0  Shooter   Ubisoft
# 1151    1153                    Far Cry 2     X360  2008.0   Action   Ubisoft
# 1337    1339                    Far Cry 4      PS3  2014.0  Shooter   Ubisoft
# 1383    1385                    Far Cry 2      PS3  2008.0   Action   Ubisoft
# 2106    2108                    Far Cry 3       PC  2012.0  Shooter   Ubisoft
# 2119    2121                    Far Cry 4     X360  2014.0  Shooter   Ubisoft
# 2434    2436              Far Cry: Primal     XOne  2016.0   Action   Ubisoft
# ...

# %%
df[df["Name"].str.contains("Mario",na=False)]
# Out:
#         Rank                                               Name Platform  \
# 1          2                                  Super Mario Bros.      NES
# 2          3                                     Mario Kart Wii      Wii
# 6          7                              New Super Mario Bros.       DS
# 8          9                          New Super Mario Bros. Wii      Wii
# 11        12                                      Mario Kart DS       DS
# ...      ...                                                ...      ...
# 12770  12772       Dance Dance Revolution: Mario Mix (JP sales)       GC
# 13273  13275               Detective Conan: Marionette Symphony      3DS
# 15261  15264                                       Mario Tennis      3DS
# 16357  16360               Mario vs. Donkey Kong: Tipping Stars     WiiU
# 16542  16545  Mario & Luigi: Paper Jam & Mario Kart 7 Double...      3DS
#
#          Year       Genre           Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
df['Total_regional_sales']=(df['NA_Sales']+df['EU_Sales']+df['JP_Sales'])
df
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %% [markdown]
# this is called as feature engineering

# %%
pivot=pd.pivot_table(
    df,
    index="Genre",
    values="Global_Sales",
    aggfunc="sum"
)

print(pivot)
# Out:
#               Global_Sales
# Genre
# Action             1751.18
# Adventure           239.04
# Fighting            448.91
# Misc                809.96
# Platform            831.37
# Puzzle              244.95
# Racing              732.04
# Role-Playing        927.37
# Shooter            1037.37
# Simulation          392.20
# Sports             1330.93
# Strategy            175.12

# %% [markdown]
# this will summarize the total sales genre-wise
